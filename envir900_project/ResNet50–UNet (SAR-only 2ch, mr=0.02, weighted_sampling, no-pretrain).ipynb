# %%
#ResNet50–UNet (SAR-only 2ch, mr=0.02, weighted_sampling, no-pretrain, Tversky, AdamW + poly)
import os
import sys

REPO_PATH = "/home/hangkai/Chenchen/AIc_course_project/mmflood_repo_backup"
DATA_PATH = "/mnt/cephfs-mount/chenchen/mmflood_processed_v2"
OUTPUT_PATH = os.path.join(REPO_PATH, "output_experiments") 

if os.getcwd() != REPO_PATH:
    os.chdir(REPO_PATH)
    print(f"in: {os.getcwd()}")
else:
    print("right")

os.makedirs(OUTPUT_PATH, exist_ok=True)
# Out:
# in: /home/hangkai/Chenchen/AIc_course_project/mmflood_repo_backup

# %%
# !CUDA_VISIBLE_DEVICES=3 python run.py train \
  --name "ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly" \
  --data.path /mnt/cephfs-mount/chenchen/mmflood_processed_v2 \
  --output-folder /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch \
  \
  --data.in-channels 3 \
  --data.include-dem \
  --data.mask-body-ratio 0.02 \
  \
  --trainer.batch-size 12 \
  --trainer.max-epochs 100 \
  --trainer.patience 30 \
  \
  --model.encoder resnet101 \
  --model.decoder deeplabv3p \
  --model.no-pretrained \
  \
  --loss.target bce \
  \
  --optimizer.target adamw \
  --optimizer.lr 1e-3 \
  --optimizer.weight-decay 1e-2 \
  \
  --scheduler.target poly
# Out:
# /home/hangkai/miniconda3/envs/py310/lib/python3.10/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/hangkai/miniconda3/envs/py310/lib/python3.10/site-packages/timm/models/features.py:4: FutureWarning: Importing from timm.models.features is deprecated, please import via timm.models
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# [2025-12-03 07:18] floods.training         : INFO     - Run started
# [2025-12-03 07:18] floods.training         : INFO     - Experiment ID: ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly
# [2025-12-03 07:18] floods.training         : INFO     - Output folder: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly
# [2025-12-03 07:18] floods.training         : INFO     - Models folder: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/models
# [2025-12-03 07:18] floods.training         : INFO     - Logs folder:   /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/logs
# [2025-12-03 07:18] floods.training         : INFO     - Configuration: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/config.yaml
# [2025-12-03 07:18] floods.training         : INFO     - Using seed: 1337
# [2025-12-03 07:18] floods.training         : INFO     - Loading datasets...
# [2025-12-03 07:18] floods.prepare          : INFO     - Train transforms: Compose([
#   RandomSizedCrop(always_apply=False, p=0.8, min_max_height=(256, 512), height=512, width=512, w2h_ratio=1.0, interpolation=1),
#   Flip(always_apply=False, p=0.5),
#   RandomRotate90(always_apply=False, p=0.5),
#   ElasticTransform(always_apply=False, p=0.5, alpha=1, sigma=50, alpha_affine=50, interpolation=1, border_mode=4, value=None, mask_value=None, approximate=False, same_dxdy=False),
#   GridDistortion(always_apply=False, p=0.5, num_steps=5, distort_limit=(-0.3, 0.3), interpolation=1, border_mode=4, value=None, mask_value=None, normalized=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)Compose([
#   OneOf([
#     GaussianBlur(always_apply=False, p=0.5, blur_limit=(3, 13), sigma_limit=(0, 0)),
#     MultiplicativeNoise(always_apply=False, p=0.5, multiplier=(0.7, 1.3), per_channel=True, elementwise=True),
#   ], p=0.6),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)Compose([
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [2025-12-03 07:18] floods.prepare          : INFO     - Eval. transforms: Compose([
#   ClipNormalize(always_apply=False, p=1.0, mean=(0.049329374, 0.011776519, 142.41237), std=(0.0391287043, 0.0103687926, 81.1010422), max_pixel_value=1.0, clip_min=-30.0, clip_max=30.0),
#   ToTensorV2(always_apply=True, p=1.0, transpose_mask=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)
# [2025-12-03 07:18] floods.prepare          : INFO     - Filtering training set with 6181 images
# [2025-12-03 07:18] floods.prepare          : INFO     - Number of elements kept: 2678
# [2025-12-03 07:18] floods.prepare          : INFO     - Ratio: 0.43%
# [2025-12-03 07:18] floods.prepare          : INFO     - Filtering validation set with 559 images
# [2025-12-03 07:18] floods.prepare          : INFO     - Number of elements kept: 262
# [2025-12-03 07:18] floods.prepare          : INFO     - Ratio: 0.47%
# [2025-12-03 07:18] floods.training         : INFO     - Full sets - train set: 2678 samples, validation set: 262 samples
# /home/hangkai/miniconda3/envs/py310/lib/python3.10/site-packages/accelerate/accelerator.py:293: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# [2025-12-03 07:18] floods.prepare          : INFO     - Found an existing array of sample weights
# [2025-12-03 07:18] floods.training         : INFO     - Preparing model...
# [2025-12-03 07:18] floods.prepare          : INFO     - Returning intermediate features: False
# [2025-12-03 07:18] floods.training         : INFO     - Visualize: True, num. batches for visualization: 8
# /home/hangkai/miniconda3/envs/py310/lib/python3.10/site-packages/accelerate/accelerator.py:673: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   model.forward = torch.cuda.amp.autocast(dtype=torch.float16)(model.forward)
# [2025-12-03 07:18] floods.trainer.base     : INFO     - [Epoch  0]
# Epoch 0   - train: 100%|██████| 446/446 [07:00<00:00,  1.06batch/s, loss=0.2881]
# [2025-12-03 07:25] floods.trainer.base     : INFO     - train/iou: 0.2769
# Epoch 0   - val: 100%|██████████| 22/22 [00:02<00:00,  7.43batch/s, loss=0.1115]
# [2025-12-03 07:25] floods.trainer.base     : INFO     - val/f1: 0.3446, val/iou: 0.2082, val/precision: 0.3884, val/recall: 0.3096, val/class_iou: 0.2082, val/class_f1: 0.3446
# [2025-12-03 07:25] floods.trainer.callbacks: INFO     - [Epoch  0] Checkpoint saved: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/models/model-00_loss-0.29_iou-0.21.pth
# [2025-12-03 07:25] floods.trainer.base     : INFO     - [Epoch  1]
# Epoch 1   - train: 100%|██████| 446/446 [10:14<00:00,  1.38s/batch, loss=0.2467]
# [2025-12-03 07:35] floods.trainer.base     : INFO     - train/iou: 0.2677
# Epoch 1   - val: 100%|██████████| 22/22 [00:06<00:00,  3.36batch/s, loss=0.1210]
# [2025-12-03 07:35] floods.trainer.base     : INFO     - val/f1: 0.3811, val/iou: 0.2354, val/precision: 0.3887, val/recall: 0.3738, val/class_iou: 0.2354, val/class_f1: 0.3811
# [2025-12-03 07:35] floods.trainer.callbacks: INFO     - [Epoch  1] Checkpoint saved: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/models/model-01_loss-0.25_iou-0.24.pth
# [2025-12-03 07:35] floods.trainer.base     : INFO     - [Epoch  2]
# Epoch 2   - train: 100%|██████| 446/446 [08:08<00:00,  1.10s/batch, loss=0.2439]
# [2025-12-03 07:43] floods.trainer.base     : INFO     - train/iou: 0.3082
# Epoch 2   - val: 100%|██████████| 22/22 [00:03<00:00,  5.50batch/s, loss=0.1047]
# [2025-12-03 07:43] floods.trainer.base     : INFO     - val/f1: 0.2553, val/iou: 0.1463, val/precision: 0.4685, val/recall: 0.1754, val/class_iou: 0.1463, val/class_f1: 0.2553
# [2025-12-03 07:43] floods.trainer.callbacks: INFO     - [Epoch  2] Early stopping patience increased to: 1/30
# [2025-12-03 07:43] floods.trainer.callbacks: INFO     - [Epoch  2] No checkpoint saved
# [2025-12-03 07:43] floods.trainer.base     : INFO     - [Epoch  3]
# Epoch 3   - train: 100%|██████| 446/446 [06:54<00:00,  1.08batch/s, loss=0.2466]
# [2025-12-03 07:50] floods.trainer.base     : INFO     - train/iou: 0.3403
# Epoch 3   - val: 100%|██████████| 22/22 [00:05<00:00,  4.19batch/s, loss=0.1014]
# [2025-12-03 07:50] floods.trainer.base     : INFO     - val/f1: 0.3465, val/iou: 0.2096, val/precision: 0.3906, val/recall: 0.3114, val/class_iou: 0.2096, val/class_f1: 0.3465
# [2025-12-03 07:50] floods.trainer.callbacks: INFO     - [Epoch  3] Early stopping patience increased to: 2/30
# [2025-12-03 07:50] floods.trainer.callbacks: INFO     - [Epoch  3] No checkpoint saved
# [2025-12-03 07:50] floods.trainer.base     : INFO     - [Epoch  4]
# Epoch 4   - train: 100%|██████| 446/446 [06:58<00:00,  1.07batch/s, loss=0.2023]
# [2025-12-03 07:57] floods.trainer.base     : INFO     - train/iou: 0.3251
# Epoch 4   - val: 100%|██████████| 22/22 [00:03<00:00,  6.98batch/s, loss=0.1047]
# [2025-12-03 07:57] floods.trainer.base     : INFO     - val/f1: 0.3643, val/iou: 0.2227, val/precision: 0.4077, val/recall: 0.3292, val/class_iou: 0.2227, val/class_f1: 0.3643
# [2025-12-03 07:57] floods.trainer.callbacks: INFO     - [Epoch  4] Early stopping patience increased to: 3/30
# [2025-12-03 07:57] floods.trainer.callbacks: INFO     - [Epoch  4] No checkpoint saved
# [2025-12-03 07:57] floods.trainer.base     : INFO     - [Epoch  5]
# Epoch 5   - train: 100%|██████| 446/446 [07:16<00:00,  1.02batch/s, loss=0.3399]
# [2025-12-03 08:05] floods.trainer.base     : INFO     - train/iou: 0.3318
# Epoch 5   - val: 100%|██████████| 22/22 [00:02<00:00,  7.58batch/s, loss=0.1062]
# [2025-12-03 08:05] floods.trainer.base     : INFO     - val/f1: 0.3409, val/iou: 0.2054, val/precision: 0.3902, val/recall: 0.3026, val/class_iou: 0.2054, val/class_f1: 0.3409
# [2025-12-03 08:05] floods.trainer.callbacks: INFO     - [Epoch  5] Early stopping patience increased to: 4/30
# [2025-12-03 08:05] floods.trainer.callbacks: INFO     - [Epoch  5] No checkpoint saved
# [2025-12-03 08:05] floods.trainer.base     : INFO     - [Epoch  6]
# Epoch 6   - train: 100%|██████| 446/446 [07:34<00:00,  1.02s/batch, loss=0.2211]
# [2025-12-03 08:12] floods.trainer.base     : INFO     - train/iou: 0.3461
# Epoch 6   - val: 100%|██████████| 22/22 [00:03<00:00,  5.97batch/s, loss=0.1032]
# [2025-12-03 08:12] floods.trainer.base     : INFO     - val/f1: 0.3435, val/iou: 0.2074, val/precision: 0.3975, val/recall: 0.3024, val/class_iou: 0.2074, val/class_f1: 0.3435
# [2025-12-03 08:12] floods.trainer.callbacks: INFO     - [Epoch  6] Early stopping patience increased to: 5/30
# [2025-12-03 08:12] floods.trainer.callbacks: INFO     - [Epoch  6] No checkpoint saved
# [2025-12-03 08:12] floods.trainer.base     : INFO     - [Epoch  7]
# Epoch 7   - train: 100%|██████| 446/446 [06:08<00:00,  1.21batch/s, loss=0.3447]
# [2025-12-03 08:19] floods.trainer.base     : INFO     - train/iou: 0.3505
# Epoch 7   - val: 100%|██████████| 22/22 [00:01<00:00, 12.18batch/s, loss=0.1110]
# [2025-12-03 08:19] floods.trainer.base     : INFO     - val/f1: 0.4067, val/iou: 0.2552, val/precision: 0.4088, val/recall: 0.4045, val/class_iou: 0.2552, val/class_f1: 0.4067
# [2025-12-03 08:19] floods.trainer.callbacks: INFO     - [Epoch  7] Checkpoint saved: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/models/model-07_loss-0.34_iou-0.26.pth
# [2025-12-03 08:19] floods.trainer.base     : INFO     - [Epoch  8]
# Epoch 8   - train: 100%|██████| 446/446 [04:18<00:00,  1.73batch/s, loss=0.2248]
# [2025-12-03 08:23] floods.trainer.base     : INFO     - train/iou: 0.3539
# Epoch 8   - val: 100%|██████████| 22/22 [00:01<00:00, 11.69batch/s, loss=0.1068]
# [2025-12-03 08:23] floods.trainer.base     : INFO     - val/f1: 0.3929, val/iou: 0.2444, val/precision: 0.4137, val/recall: 0.3740, val/class_iou: 0.2444, val/class_f1: 0.3929
# [2025-12-03 08:23] floods.trainer.callbacks: INFO     - [Epoch  8] Early stopping patience increased to: 1/30
# [2025-12-03 08:23] floods.trainer.callbacks: INFO     - [Epoch  8] No checkpoint saved
# [2025-12-03 08:23] floods.trainer.base     : INFO     - [Epoch  9]
# Epoch 9   - train: 100%|██████| 446/446 [05:30<00:00,  1.35batch/s, loss=0.1705]
# [2025-12-03 08:29] floods.trainer.base     : INFO     - train/iou: 0.3496
# Epoch 9   - val: 100%|██████████| 22/22 [00:01<00:00, 11.08batch/s, loss=0.1081]
# [2025-12-03 08:29] floods.trainer.base     : INFO     - val/f1: 0.3710, val/iou: 0.2278, val/precision: 0.4136, val/recall: 0.3364, val/class_iou: 0.2278, val/class_f1: 0.3710
# [2025-12-03 08:29] floods.trainer.callbacks: INFO     - [Epoch  9] Early stopping patience increased to: 2/30
# [2025-12-03 08:29] floods.trainer.callbacks: INFO     - [Epoch  9] No checkpoint saved
# [2025-12-03 08:29] floods.trainer.base     : INFO     - [Epoch 10]
# Epoch 10  - train: 100%|██████| 446/446 [05:24<00:00,  1.38batch/s, loss=0.1774]
# [2025-12-03 08:34] floods.trainer.base     : INFO     - train/iou: 0.3721
# Epoch 10  - val: 100%|██████████| 22/22 [00:02<00:00,  9.08batch/s, loss=0.1064]
# [2025-12-03 08:34] floods.trainer.base     : INFO     - val/f1: 0.3362, val/iou: 0.2021, val/precision: 0.4208, val/recall: 0.2799, val/class_iou: 0.2021, val/class_f1: 0.3362
# [2025-12-03 08:34] floods.trainer.callbacks: INFO     - [Epoch 10] Early stopping patience increased to: 3/30
# [2025-12-03 08:34] floods.trainer.callbacks: INFO     - [Epoch 10] No checkpoint saved
# [2025-12-03 08:34] floods.trainer.base     : INFO     - [Epoch 11]
# Epoch 11  - train: 100%|██████| 446/446 [09:39<00:00,  1.30s/batch, loss=0.2578]
# [2025-12-03 08:44] floods.trainer.base     : INFO     - train/iou: 0.3486
# Epoch 11  - val: 100%|██████████| 22/22 [00:01<00:00, 11.69batch/s, loss=0.1134]
# [2025-12-03 08:44] floods.trainer.base     : INFO     - val/f1: 0.3593, val/iou: 0.2190, val/precision: 0.4239, val/recall: 0.3118, val/class_iou: 0.2190, val/class_f1: 0.3593
# [2025-12-03 08:44] floods.trainer.callbacks: INFO     - [Epoch 11] Early stopping patience increased to: 4/30
# [2025-12-03 08:44] floods.trainer.callbacks: INFO     - [Epoch 11] No checkpoint saved
# [2025-12-03 08:44] floods.trainer.base     : INFO     - [Epoch 12]
# Epoch 12  - train: 100%|██████| 446/446 [15:44<00:00,  2.12s/batch, loss=0.2301]
# [2025-12-03 09:00] floods.trainer.base     : INFO     - train/iou: 0.3746
# Epoch 12  - val: 100%|██████████| 22/22 [00:01<00:00, 11.25batch/s, loss=0.1108]
# [2025-12-03 09:00] floods.trainer.base     : INFO     - val/f1: 0.3524, val/iou: 0.2139, val/precision: 0.4050, val/recall: 0.3120, val/class_iou: 0.2139, val/class_f1: 0.3524
# [2025-12-03 09:00] floods.trainer.callbacks: INFO     - [Epoch 12] Early stopping patience increased to: 5/30
# [2025-12-03 09:00] floods.trainer.callbacks: INFO     - [Epoch 12] No checkpoint saved
# [2025-12-03 09:00] floods.trainer.base     : INFO     - [Epoch 13]
# Epoch 13  - train: 100%|██████| 446/446 [16:03<00:00,  2.16s/batch, loss=0.3644]
# [2025-12-03 09:16] floods.trainer.base     : INFO     - train/iou: 0.3646
# Epoch 13  - val: 100%|██████████| 22/22 [00:02<00:00,  9.72batch/s, loss=0.1048]
# [2025-12-03 09:16] floods.trainer.base     : INFO     - val/f1: 0.3794, val/iou: 0.2341, val/precision: 0.4224, val/recall: 0.3444, val/class_iou: 0.2341, val/class_f1: 0.3794
# [2025-12-03 09:16] floods.trainer.callbacks: INFO     - [Epoch 13] Early stopping patience increased to: 6/30
# [2025-12-03 09:16] floods.trainer.callbacks: INFO     - [Epoch 13] No checkpoint saved
# [2025-12-03 09:16] floods.trainer.base     : INFO     - [Epoch 14]
# Epoch 14  - train: 100%|██████| 446/446 [16:18<00:00,  2.19s/batch, loss=0.1556]
# [2025-12-03 09:32] floods.trainer.base     : INFO     - train/iou: 0.3612
# Epoch 14  - val: 100%|██████████| 22/22 [00:06<00:00,  3.34batch/s, loss=0.1118]
# [2025-12-03 09:32] floods.trainer.base     : INFO     - val/f1: 0.3842, val/iou: 0.2378, val/precision: 0.4307, val/recall: 0.3469, val/class_iou: 0.2378, val/class_f1: 0.3842
# [2025-12-03 09:32] floods.trainer.callbacks: INFO     - [Epoch 14] Early stopping patience increased to: 7/30
# [2025-12-03 09:32] floods.trainer.callbacks: INFO     - [Epoch 14] No checkpoint saved
# [2025-12-03 09:32] floods.trainer.base     : INFO     - [Epoch 15]
# Epoch 15  - train: 100%|██████| 446/446 [17:27<00:00,  2.35s/batch, loss=0.1565]
# [2025-12-03 09:50] floods.trainer.base     : INFO     - train/iou: 0.3703
# Epoch 15  - val: 100%|██████████| 22/22 [00:01<00:00, 11.65batch/s, loss=0.1144]
# [2025-12-03 09:50] floods.trainer.base     : INFO     - val/f1: 0.3639, val/iou: 0.2224, val/precision: 0.4362, val/recall: 0.3121, val/class_iou: 0.2224, val/class_f1: 0.3639
# [2025-12-03 09:50] floods.trainer.callbacks: INFO     - [Epoch 15] Early stopping patience increased to: 8/30
# [2025-12-03 09:50] floods.trainer.callbacks: INFO     - [Epoch 15] No checkpoint saved
# [2025-12-03 09:50] floods.trainer.base     : INFO     - [Epoch 16]
# Epoch 16  - train: 100%|██████| 446/446 [18:06<00:00,  2.44s/batch, loss=0.2426]
# [2025-12-03 10:08] floods.trainer.base     : INFO     - train/iou: 0.3713
# Epoch 16  - val: 100%|██████████| 22/22 [00:02<00:00, 10.05batch/s, loss=0.1051]
# [2025-12-03 10:08] floods.trainer.base     : INFO     - val/f1: 0.3204, val/iou: 0.1908, val/precision: 0.4153, val/recall: 0.2608, val/class_iou: 0.1908, val/class_f1: 0.3204
# [2025-12-03 10:08] floods.trainer.callbacks: INFO     - [Epoch 16] Early stopping patience increased to: 9/30
# [2025-12-03 10:08] floods.trainer.callbacks: INFO     - [Epoch 16] No checkpoint saved
# [2025-12-03 10:08] floods.trainer.base     : INFO     - [Epoch 17]
# Epoch 17  - train: 100%|██████| 446/446 [15:56<00:00,  2.14s/batch, loss=0.1943]
# [2025-12-03 10:24] floods.trainer.base     : INFO     - train/iou: 0.3945
# Epoch 17  - val: 100%|██████████| 22/22 [00:02<00:00,  9.40batch/s, loss=0.1027]
# [2025-12-03 10:24] floods.trainer.base     : INFO     - val/f1: 0.3507, val/iou: 0.2126, val/precision: 0.4341, val/recall: 0.2941, val/class_iou: 0.2126, val/class_f1: 0.3507
# [2025-12-03 10:24] floods.trainer.callbacks: INFO     - [Epoch 17] Early stopping patience increased to: 10/30
# [2025-12-03 10:24] floods.trainer.callbacks: INFO     - [Epoch 17] No checkpoint saved
# [2025-12-03 10:24] floods.trainer.base     : INFO     - [Epoch 18]
# Epoch 18  - train: 100%|██████| 446/446 [16:25<00:00,  2.21s/batch, loss=0.2078]
# [2025-12-03 10:40] floods.trainer.base     : INFO     - train/iou: 0.3968
# Epoch 18  - val: 100%|██████████| 22/22 [00:02<00:00, 10.90batch/s, loss=0.1042]
# [2025-12-03 10:40] floods.trainer.base     : INFO     - val/f1: 0.3745, val/iou: 0.2304, val/precision: 0.4347, val/recall: 0.3289, val/class_iou: 0.2304, val/class_f1: 0.3745
# [2025-12-03 10:40] floods.trainer.callbacks: INFO     - [Epoch 18] Early stopping patience increased to: 11/30
# [2025-12-03 10:40] floods.trainer.callbacks: INFO     - [Epoch 18] No checkpoint saved
# [2025-12-03 10:40] floods.trainer.base     : INFO     - [Epoch 19]
# Epoch 19  - train: 100%|██████| 446/446 [17:19<00:00,  2.33s/batch, loss=0.1390]
# [2025-12-03 10:58] floods.trainer.base     : INFO     - train/iou: 0.3966
# Epoch 19  - val: 100%|██████████| 22/22 [00:02<00:00, 10.57batch/s, loss=0.1037]
# [2025-12-03 10:58] floods.trainer.base     : INFO     - val/f1: 0.3364, val/iou: 0.2022, val/precision: 0.4064, val/recall: 0.2870, val/class_iou: 0.2022, val/class_f1: 0.3364
# [2025-12-03 10:58] floods.trainer.callbacks: INFO     - [Epoch 19] Early stopping patience increased to: 12/30
# [2025-12-03 10:58] floods.trainer.callbacks: INFO     - [Epoch 19] No checkpoint saved
# [2025-12-03 10:58] floods.trainer.base     : INFO     - [Epoch 20]
# Epoch 20  - train: 100%|██████| 446/446 [16:49<00:00,  2.26s/batch, loss=0.2646]
# [2025-12-03 11:15] floods.trainer.base     : INFO     - train/iou: 0.4103
# Epoch 20  - val: 100%|██████████| 22/22 [00:01<00:00, 12.06batch/s, loss=0.1055]
# [2025-12-03 11:15] floods.trainer.base     : INFO     - val/f1: 0.2881, val/iou: 0.1683, val/precision: 0.4952, val/recall: 0.2031, val/class_iou: 0.1683, val/class_f1: 0.2881
# [2025-12-03 11:15] floods.trainer.callbacks: INFO     - [Epoch 20] Early stopping patience increased to: 13/30
# [2025-12-03 11:15] floods.trainer.callbacks: INFO     - [Epoch 20] No checkpoint saved
# [2025-12-03 11:15] floods.trainer.base     : INFO     - [Epoch 21]
# Epoch 21  - train: 100%|██████| 446/446 [14:55<00:00,  2.01s/batch, loss=0.2804]
# [2025-12-03 11:30] floods.trainer.base     : INFO     - train/iou: 0.4101
# Epoch 21  - val: 100%|██████████| 22/22 [00:05<00:00,  4.38batch/s, loss=0.1060]
# [2025-12-03 11:30] floods.trainer.base     : INFO     - val/f1: 0.3313, val/iou: 0.1985, val/precision: 0.4884, val/recall: 0.2506, val/class_iou: 0.1985, val/class_f1: 0.3313
# [2025-12-03 11:30] floods.trainer.callbacks: INFO     - [Epoch 21] Early stopping patience increased to: 14/30
# [2025-12-03 11:30] floods.trainer.callbacks: INFO     - [Epoch 21] No checkpoint saved
# [2025-12-03 11:30] floods.trainer.base     : INFO     - [Epoch 22]
# Epoch 22  - train: 100%|██████| 446/446 [14:26<00:00,  1.94s/batch, loss=0.1683]
# [2025-12-03 11:44] floods.trainer.base     : INFO     - train/iou: 0.4039
# Epoch 22  - val: 100%|██████████| 22/22 [00:01<00:00, 12.35batch/s, loss=0.1023]
# [2025-12-03 11:44] floods.trainer.base     : INFO     - val/f1: 0.3473, val/iou: 0.2101, val/precision: 0.4552, val/recall: 0.2807, val/class_iou: 0.2101, val/class_f1: 0.3473
# [2025-12-03 11:44] floods.trainer.callbacks: INFO     - [Epoch 22] Early stopping patience increased to: 15/30
# [2025-12-03 11:44] floods.trainer.callbacks: INFO     - [Epoch 22] No checkpoint saved
# [2025-12-03 11:44] floods.trainer.base     : INFO     - [Epoch 23]
# Epoch 23  - train: 100%|██████| 446/446 [14:03<00:00,  1.89s/batch, loss=0.2548]
# [2025-12-03 11:58] floods.trainer.base     : INFO     - train/iou: 0.4169
# Epoch 23  - val: 100%|██████████| 22/22 [00:01<00:00, 12.19batch/s, loss=0.1044]
# [2025-12-03 11:58] floods.trainer.base     : INFO     - val/f1: 0.2979, val/iou: 0.1750, val/precision: 0.5064, val/recall: 0.2110, val/class_iou: 0.1750, val/class_f1: 0.2979
# [2025-12-03 11:58] floods.trainer.callbacks: INFO     - [Epoch 23] Early stopping patience increased to: 16/30
# [2025-12-03 11:58] floods.trainer.callbacks: INFO     - [Epoch 23] No checkpoint saved
# [2025-12-03 11:59] floods.trainer.base     : INFO     - [Epoch 24]
# Epoch 24  - train: 100%|██████| 446/446 [12:31<00:00,  1.69s/batch, loss=0.2748]
# [2025-12-03 12:11] floods.trainer.base     : INFO     - train/iou: 0.4142
# Epoch 24  - val: 100%|██████████| 22/22 [00:01<00:00, 11.13batch/s, loss=0.1033]
# [2025-12-03 12:11] floods.trainer.base     : INFO     - val/f1: 0.3617, val/iou: 0.2207, val/precision: 0.5161, val/recall: 0.2784, val/class_iou: 0.2207, val/class_f1: 0.3617
# [2025-12-03 12:11] floods.trainer.callbacks: INFO     - [Epoch 24] Early stopping patience increased to: 17/30
# [2025-12-03 12:11] floods.trainer.callbacks: INFO     - [Epoch 24] No checkpoint saved
# [2025-12-03 12:11] floods.trainer.base     : INFO     - [Epoch 25]
# Epoch 25  - train: 100%|██████| 446/446 [13:03<00:00,  1.76s/batch, loss=0.2337]
# [2025-12-03 12:24] floods.trainer.base     : INFO     - train/iou: 0.4116
# Epoch 25  - val: 100%|██████████| 22/22 [00:12<00:00,  1.74batch/s, loss=0.1067]
# [2025-12-03 12:24] floods.trainer.base     : INFO     - val/f1: 0.2996, val/iou: 0.1762, val/precision: 0.4433, val/recall: 0.2263, val/class_iou: 0.1762, val/class_f1: 0.2996
# [2025-12-03 12:24] floods.trainer.callbacks: INFO     - [Epoch 25] Early stopping patience increased to: 18/30
# [2025-12-03 12:24] floods.trainer.callbacks: INFO     - [Epoch 25] No checkpoint saved
# [2025-12-03 12:24] floods.trainer.base     : INFO     - [Epoch 26]
# Epoch 26  - train: 100%|██████| 446/446 [12:34<00:00,  1.69s/batch, loss=0.2447]
# [2025-12-03 12:37] floods.trainer.base     : INFO     - train/iou: 0.4218
# Epoch 26  - val: 100%|██████████| 22/22 [00:01<00:00, 11.94batch/s, loss=0.1080]
# [2025-12-03 12:37] floods.trainer.base     : INFO     - val/f1: 0.3952, val/iou: 0.2463, val/precision: 0.5711, val/recall: 0.3022, val/class_iou: 0.2463, val/class_f1: 0.3952
# [2025-12-03 12:37] floods.trainer.callbacks: INFO     - [Epoch 26] Early stopping patience increased to: 19/30
# [2025-12-03 12:37] floods.trainer.callbacks: INFO     - [Epoch 26] No checkpoint saved
# [2025-12-03 12:37] floods.trainer.base     : INFO     - [Epoch 27]
# Epoch 27  - train: 100%|██████| 446/446 [12:21<00:00,  1.66s/batch, loss=0.3190]
# [2025-12-03 12:49] floods.trainer.base     : INFO     - train/iou: 0.4192
# Epoch 27  - val: 100%|██████████| 22/22 [00:01<00:00, 11.77batch/s, loss=0.1073]
# [2025-12-03 12:49] floods.trainer.base     : INFO     - val/f1: 0.3040, val/iou: 0.1792, val/precision: 0.4345, val/recall: 0.2338, val/class_iou: 0.1792, val/class_f1: 0.3040
# [2025-12-03 12:49] floods.trainer.callbacks: INFO     - [Epoch 27] Early stopping patience increased to: 20/30
# [2025-12-03 12:49] floods.trainer.callbacks: INFO     - [Epoch 27] No checkpoint saved
# [2025-12-03 12:50] floods.trainer.base     : INFO     - [Epoch 28]
# Epoch 28  - train: 100%|██████| 446/446 [11:26<00:00,  1.54s/batch, loss=0.1893]
# [2025-12-03 13:01] floods.trainer.base     : INFO     - train/iou: 0.3957
# Epoch 28  - val: 100%|██████████| 22/22 [00:01<00:00, 11.50batch/s, loss=0.1051]
# [2025-12-03 13:01] floods.trainer.base     : INFO     - val/f1: 0.3483, val/iou: 0.2109, val/precision: 0.5137, val/recall: 0.2635, val/class_iou: 0.2109, val/class_f1: 0.3483
# [2025-12-03 13:01] floods.trainer.callbacks: INFO     - [Epoch 28] Early stopping patience increased to: 21/30
# [2025-12-03 13:01] floods.trainer.callbacks: INFO     - [Epoch 28] No checkpoint saved
# [2025-12-03 13:01] floods.trainer.base     : INFO     - [Epoch 29]
# Epoch 29  - train: 100%|██████| 446/446 [11:00<00:00,  1.48s/batch, loss=0.2230]
# [2025-12-03 13:12] floods.trainer.base     : INFO     - train/iou: 0.4105
# Epoch 29  - val: 100%|██████████| 22/22 [00:01<00:00, 12.25batch/s, loss=0.1043]
# [2025-12-03 13:12] floods.trainer.base     : INFO     - val/f1: 0.2480, val/iou: 0.1416, val/precision: 0.3966, val/recall: 0.1804, val/class_iou: 0.1416, val/class_f1: 0.2480
# [2025-12-03 13:12] floods.trainer.callbacks: INFO     - [Epoch 29] Early stopping patience increased to: 22/30
# [2025-12-03 13:12] floods.trainer.callbacks: INFO     - [Epoch 29] No checkpoint saved
# [2025-12-03 13:12] floods.trainer.base     : INFO     - [Epoch 30]
# Epoch 30  - train: 100%|██████| 446/446 [11:46<00:00,  1.58s/batch, loss=0.1334]
# [2025-12-03 13:24] floods.trainer.base     : INFO     - train/iou: 0.4222
# Epoch 30  - val: 100%|██████████| 22/22 [00:05<00:00,  4.32batch/s, loss=0.1096]
# [2025-12-03 13:24] floods.trainer.base     : INFO     - val/f1: 0.3326, val/iou: 0.1995, val/precision: 0.5395, val/recall: 0.2404, val/class_iou: 0.1995, val/class_f1: 0.3326
# [2025-12-03 13:24] floods.trainer.callbacks: INFO     - [Epoch 30] Early stopping patience increased to: 23/30
# [2025-12-03 13:24] floods.trainer.callbacks: INFO     - [Epoch 30] No checkpoint saved
# [2025-12-03 13:24] floods.trainer.base     : INFO     - [Epoch 31]
# Epoch 31  - train: 100%|██████| 446/446 [09:40<00:00,  1.30s/batch, loss=0.2538]
# [2025-12-03 13:34] floods.trainer.base     : INFO     - train/iou: 0.4133
# Epoch 31  - val: 100%|██████████| 22/22 [00:01<00:00, 12.27batch/s, loss=0.1062]
# [2025-12-03 13:34] floods.trainer.base     : INFO     - val/f1: 0.3093, val/iou: 0.1829, val/precision: 0.5379, val/recall: 0.2171, val/class_iou: 0.1829, val/class_f1: 0.3093
# [2025-12-03 13:34] floods.trainer.callbacks: INFO     - [Epoch 31] Early stopping patience increased to: 24/30
# [2025-12-03 13:34] floods.trainer.callbacks: INFO     - [Epoch 31] No checkpoint saved
# [2025-12-03 13:34] floods.trainer.base     : INFO     - [Epoch 32]
# Epoch 32  - train: 100%|██████| 446/446 [08:05<00:00,  1.09s/batch, loss=0.1674]
# [2025-12-03 13:42] floods.trainer.base     : INFO     - train/iou: 0.4274
# Epoch 32  - val: 100%|██████████| 22/22 [00:01<00:00, 12.38batch/s, loss=0.1066]
# [2025-12-03 13:42] floods.trainer.base     : INFO     - val/f1: 0.3046, val/iou: 0.1797, val/precision: 0.5509, val/recall: 0.2105, val/class_iou: 0.1797, val/class_f1: 0.3046
# [2025-12-03 13:42] floods.trainer.callbacks: INFO     - [Epoch 32] Early stopping patience increased to: 25/30
# [2025-12-03 13:42] floods.trainer.callbacks: INFO     - [Epoch 32] No checkpoint saved
# [2025-12-03 13:42] floods.trainer.base     : INFO     - [Epoch 33]
# Epoch 33  - train: 100%|██████| 446/446 [08:10<00:00,  1.10s/batch, loss=0.2589]
# [2025-12-03 13:50] floods.trainer.base     : INFO     - train/iou: 0.4216
# Epoch 33  - val: 100%|██████████| 22/22 [00:01<00:00, 11.89batch/s, loss=0.1111]
# [2025-12-03 13:50] floods.trainer.base     : INFO     - val/f1: 0.3290, val/iou: 0.1969, val/precision: 0.5266, val/recall: 0.2392, val/class_iou: 0.1969, val/class_f1: 0.3290
# [2025-12-03 13:50] floods.trainer.callbacks: INFO     - [Epoch 33] Early stopping patience increased to: 26/30
# [2025-12-03 13:50] floods.trainer.callbacks: INFO     - [Epoch 33] No checkpoint saved
# [2025-12-03 13:50] floods.trainer.base     : INFO     - [Epoch 34]
# Epoch 34  - train: 100%|██████| 446/446 [08:31<00:00,  1.15s/batch, loss=0.1470]
# [2025-12-03 13:59] floods.trainer.base     : INFO     - train/iou: 0.4407
# Epoch 34  - val: 100%|██████████| 22/22 [00:01<00:00, 12.99batch/s, loss=0.1038]
# [2025-12-03 13:59] floods.trainer.base     : INFO     - val/f1: 0.3599, val/iou: 0.2194, val/precision: 0.5174, val/recall: 0.2759, val/class_iou: 0.2194, val/class_f1: 0.3599
# [2025-12-03 13:59] floods.trainer.callbacks: INFO     - [Epoch 34] Early stopping patience increased to: 27/30
# [2025-12-03 13:59] floods.trainer.callbacks: INFO     - [Epoch 34] No checkpoint saved
# [2025-12-03 13:59] floods.trainer.base     : INFO     - [Epoch 35]
# Epoch 35  - train: 100%|██████| 446/446 [08:04<00:00,  1.09s/batch, loss=0.1947]
# [2025-12-03 14:07] floods.trainer.base     : INFO     - train/iou: 0.4312
# Epoch 35  - val: 100%|██████████| 22/22 [00:01<00:00, 11.57batch/s, loss=0.1078]
# [2025-12-03 14:07] floods.trainer.base     : INFO     - val/f1: 0.2914, val/iou: 0.1705, val/precision: 0.4632, val/recall: 0.2125, val/class_iou: 0.1705, val/class_f1: 0.2914
# [2025-12-03 14:07] floods.trainer.callbacks: INFO     - [Epoch 35] Early stopping patience increased to: 28/30
# [2025-12-03 14:07] floods.trainer.callbacks: INFO     - [Epoch 35] No checkpoint saved
# [2025-12-03 14:07] floods.trainer.base     : INFO     - [Epoch 36]
# Epoch 36  - train: 100%|██████| 446/446 [08:07<00:00,  1.09s/batch, loss=0.3270]
# [2025-12-03 14:15] floods.trainer.base     : INFO     - train/iou: 0.4409
# Epoch 36  - val: 100%|██████████| 22/22 [00:01<00:00, 12.32batch/s, loss=0.1041]
# [2025-12-03 14:15] floods.trainer.base     : INFO     - val/f1: 0.3007, val/iou: 0.1769, val/precision: 0.5214, val/recall: 0.2113, val/class_iou: 0.1769, val/class_f1: 0.3007
# [2025-12-03 14:15] floods.trainer.callbacks: INFO     - [Epoch 36] Early stopping patience increased to: 29/30
# [2025-12-03 14:15] floods.trainer.callbacks: INFO     - [Epoch 36] No checkpoint saved
# [2025-12-03 14:15] floods.trainer.base     : INFO     - [Epoch 37]
# Epoch 37  - train: 100%|██████| 446/446 [07:57<00:00,  1.07s/batch, loss=0.2427]
# [2025-12-03 14:23] floods.trainer.base     : INFO     - train/iou: 0.4410
# Epoch 37  - val: 100%|██████████| 22/22 [00:12<00:00,  1.75batch/s, loss=0.1055]
# [2025-12-03 14:23] floods.trainer.base     : INFO     - val/f1: 0.3607, val/iou: 0.2200, val/precision: 0.5071, val/recall: 0.2799, val/class_iou: 0.2200, val/class_f1: 0.3607
# [2025-12-03 14:23] floods.trainer.callbacks: INFO     - [Epoch 37] Early stopping patience increased to: 30/30
# [2025-12-03 14:23] floods.trainer.callbacks: INFO     - [Epoch 37] Early stopping triggered
# [2025-12-03 14:23] floods.trainer.base     : INFO     - [Epoch 37] Interrupting training
# [2025-12-03 14:23] floods.training         : INFO     - Training completed at epoch 37 (best iou: 0.2552)
# [2025-12-03 14:23] floods.training         : INFO     - Experiment ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly completed!

# %%
import os
import sys

os.environ["CUDA_VISIBLE_DEVICES"] = "3"  
REPO_PATH = "/home/hangkai/Chenchen/AIc_course_project/mmflood_repo_backup"
os.chdir(REPO_PATH)
sys.path.append(REPO_PATH)

print("CWD:", os.getcwd())

from floods.utils.common import prepare_logging
prepare_logging()

# TestConfig
from floods.config.testing import TestConfig

config = TestConfig(
    name="ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly",
    data={
        "path": "/mnt/cephfs-mount/chenchen/mmflood_processed_v2",
        "in_channels": 3,
        "include_dem": True,
    },
    output_folder="/mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch",
    visualize=True,
    num_samples=8,
)

from floods.testing import test
test(config)
# Out:
# CWD: /home/hangkai/Chenchen/AIc_course_project/mmflood_repo_backup
# [2025-12-03 16:28] floods.testing          : INFO     - seed                : 1337
# [2025-12-03 16:28] floods.testing          : INFO     - image_size          : 512
# [2025-12-03 16:28] floods.testing          : INFO     - trainer             : {'cpu': False, 'amp': True, 'batch_size': 12, 'num_workers': 4, 'max_epochs': 100, 'train_metrics': [<Metrics.iou: Initializer(<class 'floods.metrics.IoU'>, ignore_index=255)>], 'val_metrics': [<Metrics.f1: Initializer(<class 'floods.metrics.F1Score'>, ignore_index=255)>, <Metrics.iou: Initializer(<class 'floods.metrics.IoU'>, ignore_index=255)>, <Metrics.precision: Initializer(<class 'floods.metrics.Precision'>, ignore_index=255, reduction='macro')>, <Metrics.recall: Initializer(<class 'floods.metrics.Recall'>, ignore_index=255, reduction='macro')>], 'monitor': <Metrics.iou: Initializer(<class 'floods.metrics.IoU'>, ignore_index=255)>, 'patience': 30, 'validate_every': 1, 'temperature': 2.0, 'temp_epochs': 20}
# [2025-12-03 16:28] floods.testing          : INFO     - data                : {'path': '/mnt/cephfs-mount/chenchen/mmflood_processed_v2', 'in_channels': 3, 'include_dem': True, 'class_weights': None, 'mask_body_ratio': 0.02, 'weighted_sampling': True, 'sample_smoothing': 0.8, 'cache_hash': '7a36c951490745982c66d816eb4c1a232ed7f3b6'}
# [2025-12-03 16:28] floods.testing          : INFO     - model               : {'encoder': 'resnet101', 'decoder': 'deeplabv3p', 'pretrained': False, 'freeze': False, 'multibranch': False, 'output_stride': 16, 'act': <ActivationLayers.relu: Initializer(<class 'torch.nn.modules.activation.ReLU'>, inplace=True)>, 'norm': <NormLayers.std: <class 'torch.nn.modules.batchnorm.BatchNorm2d'>>, 'dropout2d': False, 'transforms': 'Compose([\n  RandomSizedCrop(always_apply=False, p=0.8, min_max_height=(256, 512), height=512, width=512, w2h_ratio=1.0, interpolation=1),\n  Flip(always_apply=False, p=0.5),\n  RandomRotate90(always_apply=False, p=0.5),\n  ElasticTransform(always_apply=False, p=0.5, alpha=1, sigma=50, alpha_affine=50, interpolation=1, border_mode=4, value=None, mask_value=None, approximate=False, same_dxdy=False),\n  GridDistortion(always_apply=False, p=0.5, num_steps=5, distort_limit=(-0.3, 0.3), interpolation=1, border_mode=4, value=None, mask_value=None, normalized=False),\n], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)Compose([\n  OneOf([\n    GaussianBlur(always_apply=False, p=0.5, blur_limit=(3, 13), sigma_limit=(0, 0)),\n    MultiplicativeNoise(always_apply=False, p=0.5, multiplier=(0.7, 1.3), per_channel=True, elementwise=True),\n  ], p=0.6),\n], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)Compose([\n], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)'}
# [2025-12-03 16:28] floods.testing          : INFO     - loss                : {'target': <Losses.bce: <class 'floods.losses.BCEWithLogitsLoss'>>, 'alpha': 0.6, 'beta': 0.4, 'gamma': 2.0, 'reduction': 'mean'}
# [2025-12-03 16:28] floods.testing          : INFO     - optimizer           : {'target': <Optimizers.adamw: Initializer(<class 'torch.optim.adamw.AdamW'>)>, 'lr': 0.001, 'encoder_lr': 0.001, 'decoder_lr': 0.001, 'momentum': 0.9, 'weight_decay': 0.01}
# [2025-12-03 16:28] floods.testing          : INFO     - scheduler           : {'target': <Schedulers.poly: Initializer(<class 'floods.utils.schedulers.PolynomialLRDecay'>, max_decay_steps=99, end_learning_rate=0.0001, power=3.0)>}
# [2025-12-03 16:28] floods.testing          : INFO     - debug               : False
# [2025-12-03 16:28] floods.testing          : INFO     - name                : ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly
# [2025-12-03 16:28] floods.testing          : INFO     - output_folder       : /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch
# [2025-12-03 16:28] floods.testing          : INFO     - num_samples         : 8
# [2025-12-03 16:28] floods.testing          : INFO     - visualize           : True
# [2025-12-03 16:28] floods.testing          : INFO     - comment             :
# [2025-12-03 16:28] floods.testing          : INFO     - version             : 7876d339baa6883b3eb7acea36a4fda431f6fc51
#
# /home/hangkai/miniconda3/envs/mmflood_py38/lib/python3.8/site-packages/accelerate/accelerator.py:146: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# [2025-12-03 16:28] floods.testing          : INFO     - Using seed: 1337
# [2025-12-03 16:28] floods.testing          : INFO     - Loading test dataset...
# [2025-12-03 16:28] floods.testing          : INFO     - Preparing model...
# [2025-12-03 16:28] floods.prepare          : INFO     - Returning intermediate features: False
# /home/hangkai/Chenchen/AIc_course_project/mmflood_repo_backup/floods/testing.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(str(ckpt_path), map_location="cpu"), strict=strict_load)
# [2025-12-03 16:28] floods.testing          : INFO     - Model restored from: /mnt/cephfs-mount/chenchen/mmflood_outputs_r101_dlv3p_3ch/ResNet101_DeepLabv3p_3ch_SAR+DEM_mr002_ws_BCE_adamw_poly/models/model-07_loss-0.34_iou-0.26.pth
# [2025-12-03 16:28] floods.testing          : INFO     - Storing predicted images: true
# [2025-12-03 16:28] floods.testing          : INFO     - Storing batches: 16
# Epoch 0   - test:   0%| | 0/386 [00:00<?, ?batch/s, lo
# /home/hangkai/miniconda3/envs/mmflood_py38/lib/python3.8/site-packages/accelerate/accelerator.py:304: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   model.forward = torch.cuda.amp.autocast()(model.forward)
# Epoch 0   - test: 100%|█| 386/386 [00:57<00:00,  6.71b
# [2025-12-03 16:29] floods.trainer.base     : INFO     - test/f1: 0.7928, test/iou: 0.6568, test/precision: 0.7516, test/recall: 0.8388, test/fg_iou: 0.6568, test/fg_f1: 0.7928, test/bg_iou: 0.9412, test/bg_f1: 0.9697
# [2025-12-03 16:29] floods.trainer.callbacks: WARNING  - No content to be displayed
# [2025-12-03 16:29] floods.testing          : INFO     - Testing completed, average loss: 0.1360
# [2025-12-03 16:29] floods.testing          : INFO     - Average results:
# [2025-12-03 16:29] floods.testing          : INFO     - f1                  : 0.7928
# [2025-12-03 16:29] floods.testing          : INFO     - iou                 : 0.6568
# [2025-12-03 16:29] floods.testing          : INFO     - precision           : 0.7516
# [2025-12-03 16:29] floods.testing          : INFO     - recall              : 0.8388
# [2025-12-03 16:29] floods.testing          : INFO     - fg_iou              : 0.6568
# [2025-12-03 16:29] floods.testing          : INFO     - fg_f1               : 0.7928
# [2025-12-03 16:29] floods.testing          : INFO     - bg_iou              : 0.9412
# [2025-12-03 16:29] floods.testing          : INFO     - bg_f1               : 0.9697
# [2025-12-03 16:29] floods.testing          : INFO     - Plotting confusion matrix...
# [2025-12-03 16:29] floods.testing          : INFO     - Testing done!
